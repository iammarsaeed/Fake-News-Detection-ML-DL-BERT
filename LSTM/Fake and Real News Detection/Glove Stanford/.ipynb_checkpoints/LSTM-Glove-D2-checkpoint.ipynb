# %% [markdown]
# # LSTM

# %%
# utility
import numpy as np 
import pandas as pd 
import string
import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# model
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Embedding, LSTM, Bidirectional
from tensorflow.keras.utils import to_categorical
#from tensorflow.keras.utils.np_utils import to_categorical

#nltk and sklearn
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# File path
import os
import os.path
from os import path

# Translator
import googletrans
from googletrans import Translator

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %%
orig_df=pd.read_csv('../../../Data/Real and fake news/news.csv')

orig_df.drop(orig_df.columns[[0,1]], axis = 1, inplace = True)
# orig_df.columns = ['Text', 'Label']
orig_df = orig_df.replace(to_replace=['FAKE', 'REAL'], value=[0, 1])

# %%
data = orig_df
data.head()
# Out:
#                                                 text  label
# 0  Daniel Greenfield, a Shillman Journalism Fello...      0
# 1  Google Pinterest Digg Linkedin Reddit Stumbleu...      0
# 2  U.S. Secretary of State John F. Kerry said Mon...      1
# 3  — Kaydee King (@KaydeeKing) November 9, 2016 T...      0
# 4  It's primary day in New York and front-runners...      1

# %%
sentiment =  data['label'].values

# %%
data.groupby('label').describe()
# Out:
#        text
#       count unique                                                top freq
# label
# 0      3164   3071                                                      36
# 1      3171   2989  Killing Obama administration rules, dismantlin...   58

# %%
sns.countplot(data.label)
plt.xlabel('Tweets')
plt.title('Number of Tweets')
# Out:
# /Users/syedshayanjamal/opt/anaconda3/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Number of Tweets')

# %%
print(len(data))
# Out:
# 6335

# %%
# Data Preprocessing

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
def CleanTokenize(df):
    tweets = list()
    lines = data["text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            line = clean_text(line)
        else:
            continue
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        tweets.append(words)
    return tweets

def Tokenize(df):
    tweets = list()
    lines = data["text"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            # tokenize the text
            tokens = word_tokenize(line)
        else:
            continue

        tweets.append(tokens)
    return tweets

tweets = CleanTokenize(data)
#tweets = Tokenize(data)

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['label'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %%
validation_split = 0.2
max_length = 25


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweets)
sequences = tokenizer_obj.texts_to_sequences(tweets)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['label'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

le = LabelEncoder()
sentiment = le.fit_transform(sentiment)
# transfor from a array to a vector
sentiment = sentiment.reshape(-1,1)


num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]

X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# unique tokens -  77319
# vocab size - 77320

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (5068, 25)
# Shape of y_train: (5068, 2)
# Shape of X_test_pad: (1267, 25)
# Shape of y_test: (1267, 2)

# %%
embeddings_index = {}

# Glove Stanford NLP 
f = open('glove.6B.300d.txt', encoding = "utf-8")
for line in f:
    values = line.split()
    word = values[0]
    coefs = np.asarray(values[1:], dtype='float32')
    embeddings_index[word] = coefs
f.close()

print('Found %s word vectors.' % len(embeddings_index))
# Out:
# Found 400000 word vectors.

# %%
embedding_dim = 300

embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
c = 0
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        c+=1
        embedding_matrix[i] = embedding_vector

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## LSTM Model

# %%
from tensorflow.keras import optimizers
def createModel(embedding_layer):
    model = Sequential()
    model.add(embedding_layer)
    model.add(LSTM(512, dropout=0.2, recurrent_dropout=0.50))
    model.add(Dense(2, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer = optimizers.RMSprop(learning_rate=1e-3), metrics=['acc'])
    return model

model = createModel(embedding_layer)
model.summary()
# Out:
# 2022-03-22 19:57:14.583685: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 25, 300)           23196000
#
#  lstm (LSTM)                 (None, 512)               1665024
#
#  dense (Dense)               (None, 2)                 1026
#
# =================================================================
# Total params: 24,862,050
# Trainable params: 1,666,050
# Non-trainable params: 23,196,000
# _________________________________________________________________

# %%
history = model.fit(X_train_pad, y_train, batch_size=10, epochs=20, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/20
# 507/507 - 187s - loss: 0.5147 - acc: 0.7514 - val_loss: 0.4457 - val_acc: 0.7830 - 187s/epoch - 369ms/step
# Epoch 2/20
# 507/507 - 192s - loss: 0.3869 - acc: 0.8204 - val_loss: 0.4280 - val_acc: 0.8161 - 192s/epoch - 379ms/step
# Epoch 3/20
# 507/507 - 190s - loss: 0.3251 - acc: 0.8605 - val_loss: 0.3970 - val_acc: 0.8129 - 190s/epoch - 375ms/step
# Epoch 4/20
# 507/507 - 186s - loss: 0.2590 - acc: 0.8954 - val_loss: 0.4298 - val_acc: 0.8295 - 186s/epoch - 367ms/step
# Epoch 5/20
# 507/507 - 185s - loss: 0.1975 - acc: 0.9177 - val_loss: 0.4580 - val_acc: 0.8114 - 185s/epoch - 365ms/step
# Epoch 6/20
# 507/507 - 185s - loss: 0.1406 - acc: 0.9483 - val_loss: 0.5521 - val_acc: 0.8193 - 185s/epoch - 364ms/step
# Epoch 7/20
# 507/507 - 185s - loss: 0.1081 - acc: 0.9617 - val_loss: 0.5947 - val_acc: 0.8153 - 185s/epoch - 364ms/step
# Epoch 8/20
# 507/507 - 182s - loss: 0.0717 - acc: 0.9779 - val_loss: 0.7078 - val_acc: 0.8122 - 182s/epoch - 358ms/step
# Epoch 9/20
# 507/507 - 181s - loss: 0.0579 - acc: 0.9836 - val_loss: 0.7270 - val_acc: 0.7979 - 181s/epoch - 358ms/step
# Epoch 10/20
# 507/507 - 182s - loss: 0.0407 - acc: 0.9880 - val_loss: 1.0007 - val_acc: 0.8216 - 182s/epoch - 358ms/step
# Epoch 11/20
# 507/507 - 181s - loss: 0.0342 - acc: 0.9907 - val_loss: 0.9417 - val_acc: 0.8137 - 181s/epoch - 356ms/step
# Epoch 12/20
# 507/507 - 184s - loss: 0.0385 - acc: 0.9891 - val_loss: 0.8833 - val_acc: 0.8082 - 184s/epoch - 363ms/step
# Epoch 13/20
# 507/507 - 185s - loss: 0.0202 - acc: 0.9937 - val_loss: 1.2965 - val_acc: 0.8043 - 185s/epoch - 364ms/step
# Epoch 14/20
# 507/507 - 186s - loss: 0.0295 - acc: 0.9911 - val_loss: 1.1184 - val_acc: 0.8177 - 186s/epoch - 367ms/step
# Epoch 15/20
# 507/507 - 181s - loss: 0.0221 - acc: 0.9933 - val_loss: 1.0287 - val_acc: 0.8090 - 181s/epoch - 358ms/step
# Epoch 16/20
# 507/507 - 182s - loss: 0.0170 - acc: 0.9947 - val_loss: 1.1124 - val_acc: 0.8177 - 182s/epoch - 358ms/step
# Epoch 17/20
# 507/507 - 182s - loss: 0.0226 - acc: 0.9943 - val_loss: 1.2060 - val_acc: 0.8311 - 182s/epoch - 358ms/step
# Epoch 18/20
# 507/507 - 181s - loss: 0.0177 - acc: 0.9943 - val_loss: 1.2296 - val_acc: 0.8177 - 181s/epoch - 357ms/step
# Epoch 19/20
# 507/507 - 181s - loss: 0.0153 - acc: 0.9963 - val_loss: 1.1754 - val_acc: 0.8185 - 181s/epoch - 358ms/step
# Epoch 20/20
# 507/507 - 183s - loss: 0.0121 - acc: 0.9964 - val_loss: 1.2829 - val_acc: 0.8272 - 183s/epoch - 362ms/step

# %%
results = model.evaluate(X_test_pad, y_test, batch_size=32)
# Out:
# 40/40 [==============================] - 5s 114ms/step - loss: 1.2829 - acc: 0.8272

# %%
predictions = model.predict(cnnTestData, batch_size=1024, verbose=1)

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %%
import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import KFold
# KFold cross-validation
kFold = 10
scores = []
validation_split = 0.1
max_length = 25
results = []
train_res =[]
print("LSTM with Glove.6B.300d: ")
for i in range(kFold):
    print("Fold: ", i+1)
    prediction_val = []
    Y_test = []
    scores=[]
    random_shuff = random.randint(1, 7000)
    X_train_pad, X_test_pad, y_train, y_test = train_test_split(lines_pad, to_categorical(sentiment), test_size=0.10, shuffle = True, random_state=random_shuff)
    model = createModel(embedding_layer)
    history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=1)
    
    print("Results for current fold:")
    print("Evaluation on training data")
    train_res.append(model.evaluate(X_train_pad, y_train, batch_size=128))
    
    print("Evaluation on testing data")
    results.append(model.evaluate(X_test_pad, y_test, batch_size=128))
    
    y_pred = model.predict(X_test_pad)
    for p in y_pred:
        prediction_val.append(np.argmax(p))
    for t in y_test:
        Y_test.append(np.argmax(t))
    scoreValue = accuracy_score(Y_test,prediction_val)
    scores.append(scoreValue)
# Out:
# LSTM with Glove.6B.300d:
# Fold:  1
# Epoch 1/6
# 179/179 [==============================] - 103s 554ms/step - loss: 0.5233 - acc: 0.7462 - val_loss: 0.4383 - val_acc: 0.7902
# Epoch 2/6
# 179/179 [==============================] - 91s 510ms/step - loss: 0.4016 - acc: 0.8216 - val_loss: 0.4591 - val_acc: 0.7855
# Epoch 3/6
# 179/179 [==============================] - 91s 506ms/step - loss: 0.3383 - acc: 0.8476 - val_loss: 0.3923 - val_acc: 0.8091
# Epoch 4/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.2901 - acc: 0.8700 - val_loss: 0.4451 - val_acc: 0.7855
# Epoch 5/6
# 179/179 [==============================] - 90s 505ms/step - loss: 0.2439 - acc: 0.8976 - val_loss: 0.4608 - val_acc: 0.8091
# Epoch 6/6
# 179/179 [==============================] - 90s 501ms/step - loss: 0.1951 - acc: 0.9225 - val_loss: 0.4824 - val_acc: 0.7918
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 194ms/step - loss: 0.1069 - acc: 0.9712
# Evaluation on testing data
# 5/5 [==============================] - 1s 189ms/step - loss: 0.4824 - acc: 0.7918
# Fold:  2
# Epoch 1/6
# 179/179 [==============================] - 92s 503ms/step - loss: 0.5277 - acc: 0.7476 - val_loss: 0.4865 - val_acc: 0.7603
# Epoch 2/6
# 179/179 [==============================] - 90s 501ms/step - loss: 0.3973 - acc: 0.8178 - val_loss: 0.7339 - val_acc: 0.6814
# Epoch 3/6
# 179/179 [==============================] - 90s 501ms/step - loss: 0.3371 - acc: 0.8446 - val_loss: 0.5656 - val_acc: 0.7997
# Epoch 4/6
# 179/179 [==============================] - 90s 500ms/step - loss: 0.2981 - acc: 0.8702 - val_loss: 0.4483 - val_acc: 0.8091
# Epoch 5/6
# 179/179 [==============================] - 88s 493ms/step - loss: 0.2457 - acc: 0.8972 - val_loss: 0.4256 - val_acc: 0.8281
# Epoch 6/6
# 179/179 [==============================] - 88s 494ms/step - loss: 0.1978 - acc: 0.9190 - val_loss: 0.4891 - val_acc: 0.8076
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 193ms/step - loss: 0.1155 - acc: 0.9670
# Evaluation on testing data
# 5/5 [==============================] - 1s 191ms/step - loss: 0.4891 - acc: 0.8076
# Fold:  3
# Epoch 1/6
# 179/179 [==============================] - 94s 512ms/step - loss: 0.5229 - acc: 0.7437 - val_loss: 0.4266 - val_acc: 0.7981
# Epoch 2/6
# 179/179 [==============================] - 91s 508ms/step - loss: 0.3956 - acc: 0.8214 - val_loss: 0.5418 - val_acc: 0.7508
# Epoch 3/6
# 179/179 [==============================] - 91s 509ms/step - loss: 0.3307 - acc: 0.8455 - val_loss: 0.3613 - val_acc: 0.8375
# Epoch 4/6
# 179/179 [==============================] - 89s 497ms/step - loss: 0.2861 - acc: 0.8765 - val_loss: 0.4065 - val_acc: 0.8170
# Epoch 5/6
# 179/179 [==============================] - 90s 504ms/step - loss: 0.2437 - acc: 0.8991 - val_loss: 0.4541 - val_acc: 0.8360
# Epoch 6/6
# 179/179 [==============================] - 90s 502ms/step - loss: 0.2014 - acc: 0.9151 - val_loss: 0.5086 - val_acc: 0.8155
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 8s 186ms/step - loss: 0.1925 - acc: 0.9233
# Evaluation on testing data
# 5/5 [==============================] - 1s 190ms/step - loss: 0.5086 - acc: 0.8155
# Fold:  4
# Epoch 1/6
# 179/179 [==============================] - 94s 513ms/step - loss: 0.5225 - acc: 0.7378 - val_loss: 0.6483 - val_acc: 0.7066
# Epoch 2/6
# 179/179 [==============================] - 90s 505ms/step - loss: 0.3944 - acc: 0.8181 - val_loss: 0.4203 - val_acc: 0.8139
# Epoch 3/6
# 179/179 [==============================] - 90s 503ms/step - loss: 0.3344 - acc: 0.8513 - val_loss: 0.4135 - val_acc: 0.8170
# Epoch 4/6
# 179/179 [==============================] - 90s 502ms/step - loss: 0.2874 - acc: 0.8770 - val_loss: 0.5057 - val_acc: 0.7760
# Epoch 5/6
# 179/179 [==============================] - 94s 526ms/step - loss: 0.2528 - acc: 0.8949 - val_loss: 0.4462 - val_acc: 0.7950
# Epoch 6/6
# 179/179 [==============================] - 91s 510ms/step - loss: 0.2015 - acc: 0.9144 - val_loss: 0.4649 - val_acc: 0.8218
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 188ms/step - loss: 0.1162 - acc: 0.9612
# Evaluation on testing data
# 5/5 [==============================] - 1s 193ms/step - loss: 0.4649 - acc: 0.8218
# Fold:  5
# Epoch 1/6
# 179/179 [==============================] - 95s 521ms/step - loss: 0.5108 - acc: 0.7544 - val_loss: 0.4411 - val_acc: 0.8028
# Epoch 2/6
# 179/179 [==============================] - 92s 513ms/step - loss: 0.3956 - acc: 0.8167 - val_loss: 0.4266 - val_acc: 0.8328
# Epoch 3/6
# 179/179 [==============================] - 92s 511ms/step - loss: 0.3413 - acc: 0.8484 - val_loss: 0.4142 - val_acc: 0.8170
# Epoch 4/6
# 179/179 [==============================] - 91s 509ms/step - loss: 0.2923 - acc: 0.8674 - val_loss: 0.4620 - val_acc: 0.8123
# Epoch 5/6
# 179/179 [==============================] - 91s 511ms/step - loss: 0.2412 - acc: 0.8965 - val_loss: 0.3983 - val_acc: 0.8249
# Epoch 6/6
# 179/179 [==============================] - 92s 511ms/step - loss: 0.1977 - acc: 0.9198 - val_loss: 0.4956 - val_acc: 0.8044
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 8s 187ms/step - loss: 0.1594 - acc: 0.9300
# Evaluation on testing data
# 5/5 [==============================] - 1s 187ms/step - loss: 0.4956 - acc: 0.8044
# Fold:  6
# Epoch 1/6
# 179/179 [==============================] - 93s 509ms/step - loss: 0.5300 - acc: 0.7429 - val_loss: 0.4818 - val_acc: 0.7461
# Epoch 2/6
# 179/179 [==============================] - 91s 508ms/step - loss: 0.4016 - acc: 0.8137 - val_loss: 0.4215 - val_acc: 0.8091
# Epoch 3/6
# 179/179 [==============================] - 92s 513ms/step - loss: 0.3429 - acc: 0.8472 - val_loss: 0.3936 - val_acc: 0.8470
# Epoch 4/6
# 179/179 [==============================] - 97s 539ms/step - loss: 0.2940 - acc: 0.8674 - val_loss: 0.3909 - val_acc: 0.8297
# Epoch 5/6
# 179/179 [==============================] - 93s 518ms/step - loss: 0.2474 - acc: 0.8928 - val_loss: 0.4430 - val_acc: 0.8281
# Epoch 6/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.2067 - acc: 0.9165 - val_loss: 0.5053 - val_acc: 0.7981
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 194ms/step - loss: 0.1769 - acc: 0.9369
# Evaluation on testing data
# 5/5 [==============================] - 1s 195ms/step - loss: 0.5053 - acc: 0.7981
# Fold:  7
# Epoch 1/6
# 179/179 [==============================] - 96s 523ms/step - loss: 0.5204 - acc: 0.7467 - val_loss: 0.5257 - val_acc: 0.7539
# Epoch 2/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.3970 - acc: 0.8170 - val_loss: 0.4442 - val_acc: 0.7855
# Epoch 3/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.3337 - acc: 0.8530 - val_loss: 0.4365 - val_acc: 0.7997
# Epoch 4/6
# 179/179 [==============================] - 93s 522ms/step - loss: 0.2858 - acc: 0.8744 - val_loss: 0.6497 - val_acc: 0.7729
# Epoch 5/6
# 179/179 [==============================] - 92s 516ms/step - loss: 0.2409 - acc: 0.9014 - val_loss: 0.5834 - val_acc: 0.7729
# Epoch 6/6
# 179/179 [==============================] - 93s 518ms/step - loss: 0.1870 - acc: 0.9191 - val_loss: 0.4940 - val_acc: 0.8139
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 198ms/step - loss: 0.1166 - acc: 0.9568
# Evaluation on testing data
# 5/5 [==============================] - 1s 192ms/step - loss: 0.4940 - acc: 0.8139
# Fold:  8
# Epoch 1/6
# 179/179 [==============================] - 98s 537ms/step - loss: 0.5238 - acc: 0.7478 - val_loss: 0.4656 - val_acc: 0.7697
# Epoch 2/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.4010 - acc: 0.8167 - val_loss: 0.4227 - val_acc: 0.8218
# Epoch 3/6
# 179/179 [==============================] - 92s 516ms/step - loss: 0.3448 - acc: 0.8451 - val_loss: 0.4043 - val_acc: 0.8028
# Epoch 4/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.2816 - acc: 0.8793 - val_loss: 0.5076 - val_acc: 0.8107
# Epoch 5/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.2446 - acc: 0.8981 - val_loss: 0.5315 - val_acc: 0.7776
# Epoch 6/6
# 179/179 [==============================] - 89s 500ms/step - loss: 0.2115 - acc: 0.9123 - val_loss: 0.5136 - val_acc: 0.7997
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 8s 181ms/step - loss: 0.1269 - acc: 0.9590
# Evaluation on testing data
# 5/5 [==============================] - 1s 183ms/step - loss: 0.5136 - acc: 0.7997
# Fold:  9
# Epoch 1/6
# 179/179 [==============================] - 92s 501ms/step - loss: 0.5163 - acc: 0.7530 - val_loss: 0.5004 - val_acc: 0.7461
# Epoch 2/6
# 179/179 [==============================] - 90s 501ms/step - loss: 0.3954 - acc: 0.8179 - val_loss: 0.4935 - val_acc: 0.7950
# Epoch 3/6
# 179/179 [==============================] - 92s 514ms/step - loss: 0.3283 - acc: 0.8606 - val_loss: 0.4942 - val_acc: 0.7650
# Epoch 4/6
# 179/179 [==============================] - 91s 508ms/step - loss: 0.2815 - acc: 0.8791 - val_loss: 0.4871 - val_acc: 0.7855
# Epoch 5/6
# 179/179 [==============================] - 93s 520ms/step - loss: 0.2343 - acc: 0.8977 - val_loss: 0.5442 - val_acc: 0.7744
# Epoch 6/6
# 179/179 [==============================] - 91s 508ms/step - loss: 0.1915 - acc: 0.9246 - val_loss: 0.5639 - val_acc: 0.7918
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 9s 194ms/step - loss: 0.1361 - acc: 0.9453
# Evaluation on testing data
# 5/5 [==============================] - 1s 188ms/step - loss: 0.5639 - acc: 0.7918
# Fold:  10
# Epoch 1/6
# 179/179 [==============================] - 94s 513ms/step - loss: 0.5212 - acc: 0.7478 - val_loss: 0.4991 - val_acc: 0.7397
# Epoch 2/6
# 179/179 [==============================] - 91s 506ms/step - loss: 0.4003 - acc: 0.8125 - val_loss: 0.4788 - val_acc: 0.7902
# Epoch 3/6
# 179/179 [==============================] - 92s 512ms/step - loss: 0.3409 - acc: 0.8465 - val_loss: 0.3584 - val_acc: 0.8281
# Epoch 4/6
# 179/179 [==============================] - 94s 524ms/step - loss: 0.2944 - acc: 0.8744 - val_loss: 0.4254 - val_acc: 0.7997
# Epoch 5/6
# 179/179 [==============================] - 96s 536ms/step - loss: 0.2422 - acc: 0.8930 - val_loss: 0.4542 - val_acc: 0.8091
# Epoch 6/6
# 179/179 [==============================] - 92s 515ms/step - loss: 0.1918 - acc: 0.9216 - val_loss: 0.4915 - val_acc: 0.8139
# Results for current fold:
# Evaluation on training data
# 45/45 [==============================] - 8s 186ms/step - loss: 0.1723 - acc: 0.9237
# Evaluation on testing data
# 5/5 [==============================] - 1s 186ms/step - loss: 0.4915 - acc: 0.8139

# %%
import statistics 

# mean_scores = statistics.mean(scores)
# print("predicted value", mean_scores)
score = []
for i in results:
    score.append(i[1])
x = statistics.mean(score)
    
print("Kfold Mean: ", x)
# Out:
# Kfold Mean:  0.8058359682559967

# %%
results2 = confusion_matrix(Y_test,prediction_val)
print ('Confusion Matrix :')
print(results2) 
print ('Accuracy Score :',accuracy_score(Y_test,prediction_val))
print ('Report : ')
print (classification_report(Y_test,prediction_val))
# Out:
# Confusion Matrix :
# [[285  27]
#  [ 91 231]]
# Accuracy Score : 0.8138801261829653
# Report :
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83       312
#            1       0.90      0.72      0.80       322
#
#     accuracy                           0.81       634
#    macro avg       0.83      0.82      0.81       634
# weighted avg       0.83      0.81      0.81       634
