# %% [markdown]
# # LSTM

# %%
# utility
import numpy as np 
import pandas as pd 
import string
import re

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix

# model 
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Dense, Embedding, LSTM, Bidirectional
import keras
from keras.utils.np_utils import to_categorical

#nltk and sklearn
from sklearn.preprocessing import LabelEncoder
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# File path
import os
import os.path
from os import path

# Translator
import googletrans
from googletrans import Translator

# calc accuracy
from sklearn.metrics import accuracy_score 
from sklearn.metrics import classification_report

# %% [markdown]
# ### Data

# %%
orig_df=pd.read_csv('../../../Data/Fake news detection/data.csv')
orig_df.drop(orig_df.columns[[0,1]], axis = 1, inplace = True)
orig_df["Body"] = orig_df["Body"].astype(str)
orig_df["Label"] = orig_df["Label"].astype(str)

# %%
df = orig_df
df.head()
# Out:
#                                                 Body  Label
# 0  Image copyright Getty Images\nOn Sunday mornin...      1
# 1  LONDON (Reuters) - “Last Flag Flying”, a comed...      1
# 2  The feud broke into public view last week when...      1
# 3  MEXICO CITY (Reuters) - Egypt’s Cheiron Holdin...      1
# 4  Country singer Jason Aldean, who was performin...      1

# %%
sentiment =  df['Label'].values

# %%
df.groupby('Label').describe()
# Out:
#        Body
#       count unique                                                top freq
# Label
# 0      2120   1193  A Potato Battery Can Light up a Room for Over ...  143
# 1      1868   1670  Chat with us in Facebook Messenger. Find out w...   61

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=(6,4))
df.groupby('Label').Body.count().plot.bar(ylim=0)
plt.show()

# %%
# For entire dataset sentences for each labels 
df.Label.value_counts()
# Out:
# 0    2137
# 1    1872
# Name: Label, dtype: int64

# %% [markdown]
# ### Balanced Data

# %%
#balancing data 
from collections import Counter
import numpy as np
def balanceClasses(xs, ys):
    item = {}
    new_ys = []
    new_xs = []
    #"""Undersample xs, ys to balance classes."""
    freqs = Counter(ys)
    # the most common class  is the maximum number we want for all classes
    max_allowable = (freqs.most_common()[0][1])
    
    for val in freqs.most_common(): # List
        nums = np.random.randint(1000)
        i = 1
        item[val[0]] = max_allowable - val[1]
        
        if item[val[0]] > 0:            
            while(item[val[0]] - i != 0): 
                nums = nums + 1
                if ys[nums] == val[0]:
                    i += 1
                    new_ys.append(ys[nums])
                    new_xs.append(xs[nums])
    return new_xs, new_ys

# %%
new_text, new_label = balanceClasses(df['Body'], df['Label'])

# %%
data = pd.DataFrame(new_text)
data.columns = ['Body']
data['Label'] = new_label
data = pd.concat([df, data])

# %%
fig1 = plt.figure(figsize=(6,4))
data.groupby('Label').Body.count().plot.bar(ylim=0)
plt.show()

# %%
data.Label.value_counts()
# Out:
# 0    2137
# 1    2136
# Name: Label, dtype: int64

# %%
# For entire dataset sentences for each labels 
data.Label.value_counts()
# Out:
# 0    2137
# 1    2136
# Name: Label, dtype: int64

# %%
data=data.sample(frac=1).reset_index(drop=True)
data
# Out:
#                                                    Body  Label
# 0     The Islanders are combining forces with the ow...      1
# 1     The investigation into Luxembourg’s handling o...      1
# 2     They get into Formula 1 early in Japan: Lewis ...      1
# 3     FILE PHOTO - Senator Chuck Grassley (R-IA) ask...      1
# 4     An Embattled Pharmaceutical Company That Sells...      0
# ...                                                 ...    ...
# 4268  Respected Liberal Writer Blames Vegas Shooting...      0
# 4269  A Potato Battery Can Light up a Room for Over ...      0
# 4270  Ryan Gosling, Guy On A Boat Give Dating Advice...      0
# 4271  Red Flag Warning: These California Wildfires A...      0
# 4272  James Harding, the head of BBC's news and curr...      1
#
# [4273 rows x 2 columns]

# %% [markdown]
# ### Data Preprocessing

# %%
def clean_text(text):
    text = text.lower()
    
    pattern = re.compile('http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+')
    text = pattern.sub('', text)
    text = " ".join(filter(lambda x:x[0]!='@', text.split()))
    text = text.lower()
    text = re.sub(r"i'm", "i am", text)
    text = re.sub(r"he's", "he is", text)
    text = re.sub(r"she's", "she is", text)
    text = re.sub(r"that's", "that is", text)        
    text = re.sub(r"what's", "what is", text)
    text = re.sub(r"where's", "where is", text) 
    text = re.sub(r"\'ll", " will", text)  
    text = re.sub(r"\'ve", " have", text)  
    text = re.sub(r"\'re", " are", text)
    text = re.sub(r"\'d", " would", text)
    text = re.sub(r"\'ve", " have", text)
    text = re.sub(r"won't", "will not", text)
    text = re.sub(r"don't", "do not", text)
    text = re.sub(r"did't", "did not", text)
    text = re.sub(r"can't", "can not", text)
    text = re.sub(r"it's", "it is", text)
    text = re.sub(r"couldn't", "could not", text)
    text = re.sub(r"have't", "have not", text)
    text = re.sub(r"[,.\"\'!@#$%^&*(){}?/;`~:<>+=-]", "", text)
    return text

# %%
def CleanTokenize(df):
    tweets = list()
    lines = data["Body"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            line = clean_text(line)
        else:
            continue
        # tokenize the text
        tokens = word_tokenize(line)
        # remove puntuations
        table = str.maketrans('', '', string.punctuation)
        stripped = [w.translate(table) for w in tokens]
        # remove non alphabetic characters
        words = [word for word in stripped if word.isalpha()]
        stop_words = set(stopwords.words("english"))
        # remove stop words
        words = [w for w in words if not w in stop_words]
        tweets.append(words)
    return tweets

def Tokenize(df):
    tweets = list()
    lines = data["Body"].values.tolist()
    
    for line in lines:
        if isinstance(line, str):
            # tokenize the text
            tokens = word_tokenize(line)
        else:
            continue

        tweets.append(tokens)
    return tweets

tweets = CleanTokenize(data)
#tweets = Tokenize(data)

# %%
from collections import Counter
from wordcloud import WordCloud, ImageColorGenerator
pos_data = data.loc[data['Label'] == 1]
pos_head_lines = CleanTokenize(pos_data)
pos_lines = [j for sub in pos_head_lines for j in sub] 
word_could_dict=Counter(pos_lines)

wordcloud = WordCloud(width = 1000, height = 500).generate_from_frequencies(word_could_dict)
plt.figure(figsize=(15,8))
plt.imshow(wordcloud)
plt.axis("off")
# Out:
# (-0.5, 999.5, 499.5, -0.5)

# %% [markdown]
# ### Splitting data

# %%
validation_split = 0.1
max_length = 25


tokenizer_obj = Tokenizer()
tokenizer_obj.fit_on_texts(tweets)
sequences = tokenizer_obj.texts_to_sequences(tweets)

word_index = tokenizer_obj.word_index
print("unique tokens - ",len(word_index))
vocab_size = len(tokenizer_obj.word_index) + 1
print('vocab size -', vocab_size)

lines_pad = pad_sequences(sequences, maxlen=max_length, padding='post')
sentiment =  data['Label'].values

indices = np.arange(lines_pad.shape[0])
np.random.shuffle(indices)
lines_pad = lines_pad[indices]
sentiment = sentiment[indices]

le = LabelEncoder()
sentiment = le.fit_transform(sentiment)
# transfor from a array to a vector
sentiment = sentiment.reshape(-1,1)


num_validation_samples = int(validation_split * lines_pad.shape[0])

X_train_pad = lines_pad[:-num_validation_samples]
y_train = sentiment[:-num_validation_samples]

X_test_pad = lines_pad[-num_validation_samples:]
y_test = sentiment[-num_validation_samples:]

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)
# Out:
# unique tokens -  49054
# vocab size - 49055

# %%
print('Shape of X_train_pad:', X_train_pad.shape)
print('Shape of y_train:', y_train.shape)

print('Shape of X_test_pad:', X_test_pad.shape)
print('Shape of y_test:', y_test.shape)
# Out:
# Shape of X_train_pad: (3826, 25)
# Shape of y_train: (3826, 2)
# Shape of X_test_pad: (425, 25)
# Shape of y_test: (425, 2)

# %% [markdown]
# ### Word2vec Word Embedding

# %%
from gensim import models
word2vec_path = 'GoogleNews-vectors-negative300.bin'
word2vec = models.KeyedVectors.load_word2vec_format(word2vec_path, binary=True)

# %%
embedding_dim = 300

embedding_matrix = np.zeros((len(word_index) + 1, embedding_dim))
for word, i in word_index.items():
    embedding_matrix[i,:] = word2vec[word] if word in word2vec else np.random.rand(embedding_dim)
print()

# %%
embedding_layer = Embedding(len(word_index) + 1,
                            embedding_dim,
                            weights=[embedding_matrix],
                            input_length=max_length,
                            trainable=False)

# %% [markdown]
# ## LSTM Model

# %%
from tensorflow.keras import optimizers
def createModel(embedding_layer):
    model = Sequential()
    model.add(embedding_layer)
    model.add(LSTM(256, dropout=0.2, recurrent_dropout=0.50))
    model.add(Dense(2, activation='softmax'))

    model.compile(loss='categorical_crossentropy', optimizer = optimizers.RMSprop(learning_rate=1e-3), metrics=['acc'])
    return model

model = createModel(embedding_layer)
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 25, 300)           14716500
#
#  lstm_11 (LSTM)              (None, 256)               570368
#
#  dense_11 (Dense)            (None, 2)                 514
#
# =================================================================
# Total params: 15,287,382
# Trainable params: 570,882
# Non-trainable params: 14,716,500
# _________________________________________________________________

# %%
history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=2)
# Out:
# Epoch 1/6
# 120/120 - 28s - loss: 0.7034 - acc: 0.4976 - val_loss: 0.6944 - val_acc: 0.5129 - 28s/epoch - 234ms/step
# Epoch 2/6
# 120/120 - 21s - loss: 0.6903 - acc: 0.5311 - val_loss: 0.6994 - val_acc: 0.4918 - 21s/epoch - 174ms/step
# Epoch 3/6
# 120/120 - 21s - loss: 0.6814 - acc: 0.5499 - val_loss: 0.6977 - val_acc: 0.4941 - 21s/epoch - 178ms/step
# Epoch 4/6
# 120/120 - 22s - loss: 0.6679 - acc: 0.5876 - val_loss: 0.7125 - val_acc: 0.4965 - 22s/epoch - 186ms/step
# Epoch 5/6
# 120/120 - 23s - loss: 0.6544 - acc: 0.6009 - val_loss: 0.7187 - val_acc: 0.5294 - 23s/epoch - 189ms/step
# Epoch 6/6
# 120/120 - 22s - loss: 0.6448 - acc: 0.6174 - val_loss: 0.7180 - val_acc: 0.5129 - 22s/epoch - 185ms/step

# %%
results = model.evaluate(X_test_pad, y_test, batch_size=32)
# Out:
# 14/14 [==============================] - 1s 53ms/step - loss: 0.7180 - acc: 0.5129

# %%
# Plot results
acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc)+1)

plt.plot(epochs, acc, 'g', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'g', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()

# %% [markdown]
# ### 10 Fold cross validation

# %%
import random
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score 
from sklearn.model_selection import KFold
# KFold cross-validation
kFold = 10
scores = []
validation_split = 0.1
max_length = 25
results = []
train_results = []
print("LSTM with Word2Vec: ")
for i in range(kFold):
    print("Fold: ", i+1)
    prediction_val = []
    Y_test = []
    scores=[]
    random_shuff = random.randint(1, 7000)
    X_train_pad, X_test_pad, y_train, y_test = train_test_split(lines_pad, to_categorical(sentiment), test_size=0.10, shuffle = True, random_state=random_shuff)
    model = createModel(embedding_layer)
    history = model.fit(X_train_pad, y_train, batch_size=32, epochs=6, validation_data=(X_test_pad, y_test), verbose=1)
    
    print("Results for current fold:")
    print("Evaluation using training data")
    train_results.append(model.evaluate(X_train_pad, y_train, batch_size=128))
    print("Evaluation using testing data")
    results.append(model.evaluate(X_test_pad, y_test, batch_size=128))
    
    y_pred = model.predict(X_test_pad)
    for p in y_pred:
        prediction_val.append(np.argmax(p))
    for t in y_test:
        Y_test.append(np.argmax(t))
    scoreValue = accuracy_score(Y_test,prediction_val)
    scores.append(scoreValue)
# Out:
# LSTM with Word2Vec:
# Fold:  1
# Epoch 1/6
# 120/120 [==============================] - 25s 190ms/step - loss: 0.7025 - acc: 0.5001 - val_loss: 0.6936 - val_acc: 0.5211
# Epoch 2/6
# 120/120 [==============================] - 25s 209ms/step - loss: 0.6901 - acc: 0.5370 - val_loss: 0.6934 - val_acc: 0.5399
# Epoch 3/6
# 120/120 [==============================] - 31s 259ms/step - loss: 0.6822 - acc: 0.5563 - val_loss: 0.6988 - val_acc: 0.4977
# Epoch 4/6
# 120/120 [==============================] - 24s 204ms/step - loss: 0.6708 - acc: 0.5856 - val_loss: 0.6997 - val_acc: 0.5305
# Epoch 5/6
# 120/120 [==============================] - 22s 187ms/step - loss: 0.6583 - acc: 0.6084 - val_loss: 0.7213 - val_acc: 0.4977
# Epoch 6/6
# 120/120 [==============================] - 23s 194ms/step - loss: 0.6457 - acc: 0.6042 - val_loss: 0.7117 - val_acc: 0.5258
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 95ms/step - loss: 0.6043 - acc: 0.6761
# Evaluation using testing data
# 4/4 [==============================] - 0s 98ms/step - loss: 0.7117 - acc: 0.5258
# Fold:  2
# Epoch 1/6
# 120/120 [==============================] - 26s 189ms/step - loss: 0.7009 - acc: 0.5051 - val_loss: 0.7095 - val_acc: 0.4390
# Epoch 2/6
# 120/120 [==============================] - 23s 188ms/step - loss: 0.6910 - acc: 0.5312 - val_loss: 0.7034 - val_acc: 0.4742
# Epoch 3/6
# 120/120 [==============================] - 23s 189ms/step - loss: 0.6808 - acc: 0.5579 - val_loss: 0.7023 - val_acc: 0.5070
# Epoch 4/6
# 120/120 [==============================] - 23s 193ms/step - loss: 0.6708 - acc: 0.5765 - val_loss: 0.7713 - val_acc: 0.4765
# Epoch 5/6
# 120/120 [==============================] - 22s 187ms/step - loss: 0.6528 - acc: 0.6047 - val_loss: 0.7284 - val_acc: 0.4789
# Epoch 6/6
# 120/120 [==============================] - 23s 193ms/step - loss: 0.6468 - acc: 0.6120 - val_loss: 0.7497 - val_acc: 0.4695
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 93ms/step - loss: 0.6097 - acc: 0.6677
# Evaluation using testing data
# 4/4 [==============================] - 0s 82ms/step - loss: 0.7497 - acc: 0.4695
# Fold:  3
# Epoch 1/6
# 120/120 [==============================] - 28s 212ms/step - loss: 0.7017 - acc: 0.5048 - val_loss: 0.6934 - val_acc: 0.5352
# Epoch 2/6
# 120/120 [==============================] - 23s 189ms/step - loss: 0.6915 - acc: 0.5184 - val_loss: 0.6949 - val_acc: 0.5164
# Epoch 3/6
# 120/120 [==============================] - 23s 189ms/step - loss: 0.6804 - acc: 0.5637 - val_loss: 0.6996 - val_acc: 0.5376
# Epoch 4/6
# 120/120 [==============================] - 22s 183ms/step - loss: 0.6708 - acc: 0.5765 - val_loss: 0.7042 - val_acc: 0.5211
# Epoch 5/6
# 120/120 [==============================] - 23s 191ms/step - loss: 0.6571 - acc: 0.5903 - val_loss: 0.7263 - val_acc: 0.5117
# Epoch 6/6
# 120/120 [==============================] - 23s 189ms/step - loss: 0.6439 - acc: 0.6149 - val_loss: 0.7182 - val_acc: 0.5141
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 96ms/step - loss: 0.6171 - acc: 0.6680
# Evaluation using testing data
# 4/4 [==============================] - 0s 90ms/step - loss: 0.7182 - acc: 0.5141
# Fold:  4
# Epoch 1/6
# 120/120 [==============================] - 27s 186ms/step - loss: 0.7055 - acc: 0.5051 - val_loss: 0.7027 - val_acc: 0.4812
# Epoch 2/6
# 120/120 [==============================] - 23s 187ms/step - loss: 0.6908 - acc: 0.5242 - val_loss: 0.6984 - val_acc: 0.5047
# Epoch 3/6
# 120/120 [==============================] - 23s 190ms/step - loss: 0.6810 - acc: 0.5584 - val_loss: 0.7005 - val_acc: 0.5047
# Epoch 4/6
# 120/120 [==============================] - 22s 182ms/step - loss: 0.6702 - acc: 0.5762 - val_loss: 0.7086 - val_acc: 0.4930
# Epoch 5/6
# 120/120 [==============================] - 22s 183ms/step - loss: 0.6548 - acc: 0.6058 - val_loss: 0.7216 - val_acc: 0.4883
# Epoch 6/6
# 120/120 [==============================] - 22s 185ms/step - loss: 0.6442 - acc: 0.6167 - val_loss: 0.7619 - val_acc: 0.4930
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 110ms/step - loss: 0.6062 - acc: 0.6586
# Evaluation using testing data
# 4/4 [==============================] - 0s 94ms/step - loss: 0.7619 - acc: 0.4930
# Fold:  5
# Epoch 1/6
# 120/120 [==============================] - 26s 196ms/step - loss: 0.7052 - acc: 0.4959 - val_loss: 0.6960 - val_acc: 0.5188
# Epoch 2/6
# 120/120 [==============================] - 24s 196ms/step - loss: 0.6912 - acc: 0.5328 - val_loss: 0.6995 - val_acc: 0.5117
# Epoch 3/6
# 120/120 [==============================] - 23s 195ms/step - loss: 0.6817 - acc: 0.5535 - val_loss: 0.6953 - val_acc: 0.5493
# Epoch 4/6
# 120/120 [==============================] - 24s 200ms/step - loss: 0.6706 - acc: 0.5788 - val_loss: 0.7068 - val_acc: 0.5023
# Epoch 5/6
# 120/120 [==============================] - 23s 196ms/step - loss: 0.6571 - acc: 0.6076 - val_loss: 0.7503 - val_acc: 0.4648
# Epoch 6/6
# 120/120 [==============================] - 24s 200ms/step - loss: 0.6399 - acc: 0.6275 - val_loss: 0.7323 - val_acc: 0.5211
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 100ms/step - loss: 0.6034 - acc: 0.6876
# Evaluation using testing data
# 4/4 [==============================] - 0s 91ms/step - loss: 0.7323 - acc: 0.5211
# Fold:  6
# Epoch 1/6
# 120/120 [==============================] - 27s 204ms/step - loss: 0.7038 - acc: 0.4918 - val_loss: 0.6950 - val_acc: 0.5211
# Epoch 2/6
# 120/120 [==============================] - 26s 213ms/step - loss: 0.6904 - acc: 0.5299 - val_loss: 0.6941 - val_acc: 0.5235
# Epoch 3/6
# 120/120 [==============================] - 24s 196ms/step - loss: 0.6801 - acc: 0.5558 - val_loss: 0.7076 - val_acc: 0.4765
# Epoch 4/6
# 120/120 [==============================] - 23s 195ms/step - loss: 0.6705 - acc: 0.5888 - val_loss: 0.7094 - val_acc: 0.4859
# Epoch 5/6
# 120/120 [==============================] - 24s 202ms/step - loss: 0.6597 - acc: 0.6013 - val_loss: 0.7072 - val_acc: 0.5000
# Epoch 6/6
# 120/120 [==============================] - 26s 214ms/step - loss: 0.6462 - acc: 0.6063 - val_loss: 0.7322 - val_acc: 0.5000
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 4s 135ms/step - loss: 0.5975 - acc: 0.6831
# Evaluation using testing data
# 4/4 [==============================] - 0s 117ms/step - loss: 0.7322 - acc: 0.5000
# Fold:  7
# Epoch 1/6
# 120/120 [==============================] - 27s 199ms/step - loss: 0.7040 - acc: 0.4965 - val_loss: 0.6972 - val_acc: 0.5188
# Epoch 2/6
# 120/120 [==============================] - 24s 199ms/step - loss: 0.6909 - acc: 0.5354 - val_loss: 0.7009 - val_acc: 0.4789
# Epoch 3/6
# 120/120 [==============================] - 24s 203ms/step - loss: 0.6803 - acc: 0.5697 - val_loss: 0.7048 - val_acc: 0.5164
# Epoch 4/6
# 120/120 [==============================] - 25s 205ms/step - loss: 0.6672 - acc: 0.5864 - val_loss: 0.7040 - val_acc: 0.5070
# Epoch 5/6
# 120/120 [==============================] - 23s 193ms/step - loss: 0.6539 - acc: 0.6144 - val_loss: 0.7174 - val_acc: 0.4859
# Epoch 6/6
# 120/120 [==============================] - 27s 221ms/step - loss: 0.6410 - acc: 0.6288 - val_loss: 0.7141 - val_acc: 0.5070
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 97ms/step - loss: 0.6208 - acc: 0.6544
# Evaluation using testing data
# 4/4 [==============================] - 0s 89ms/step - loss: 0.7141 - acc: 0.5070
# Fold:  8
# Epoch 1/6
# 120/120 [==============================] - 26s 193ms/step - loss: 0.7060 - acc: 0.4824 - val_loss: 0.6895 - val_acc: 0.5446
# Epoch 2/6
# 120/120 [==============================] - 23s 191ms/step - loss: 0.6918 - acc: 0.5273 - val_loss: 0.6867 - val_acc: 0.5469
# Epoch 3/6
# 120/120 [==============================] - 23s 194ms/step - loss: 0.6841 - acc: 0.5516 - val_loss: 0.6938 - val_acc: 0.5164
# Epoch 4/6
# 120/120 [==============================] - 23s 188ms/step - loss: 0.6716 - acc: 0.5796 - val_loss: 0.6958 - val_acc: 0.5352
# Epoch 5/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6630 - acc: 0.5901 - val_loss: 0.7179 - val_acc: 0.5376
# Epoch 6/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6499 - acc: 0.6118 - val_loss: 0.7354 - val_acc: 0.5188
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 95ms/step - loss: 0.6140 - acc: 0.6651
# Evaluation using testing data
# 4/4 [==============================] - 0s 83ms/step - loss: 0.7354 - acc: 0.5188
# Fold:  9
# Epoch 1/6
# 120/120 [==============================] - 28s 208ms/step - loss: 0.7057 - acc: 0.4923 - val_loss: 0.6925 - val_acc: 0.4953
# Epoch 2/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6917 - acc: 0.5323 - val_loss: 0.6897 - val_acc: 0.5258
# Epoch 3/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6833 - acc: 0.5524 - val_loss: 0.7105 - val_acc: 0.4953
# Epoch 4/6
# 120/120 [==============================] - 23s 194ms/step - loss: 0.6740 - acc: 0.5856 - val_loss: 0.6913 - val_acc: 0.5352
# Epoch 5/6
# 120/120 [==============================] - 23s 191ms/step - loss: 0.6615 - acc: 0.5885 - val_loss: 0.7074 - val_acc: 0.5164
# Epoch 6/6
# 120/120 [==============================] - 23s 193ms/step - loss: 0.6418 - acc: 0.6254 - val_loss: 0.7093 - val_acc: 0.5211
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 98ms/step - loss: 0.6110 - acc: 0.6790
# Evaluation using testing data
# 4/4 [==============================] - 0s 91ms/step - loss: 0.7093 - acc: 0.5211
# Fold:  10
# Epoch 1/6
# 120/120 [==============================] - 26s 196ms/step - loss: 0.7038 - acc: 0.4928 - val_loss: 0.7021 - val_acc: 0.4624
# Epoch 2/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6912 - acc: 0.5393 - val_loss: 0.6973 - val_acc: 0.4577
# Epoch 3/6
# 120/120 [==============================] - 23s 193ms/step - loss: 0.6810 - acc: 0.5634 - val_loss: 0.6999 - val_acc: 0.4695
# Epoch 4/6
# 120/120 [==============================] - 24s 197ms/step - loss: 0.6699 - acc: 0.5759 - val_loss: 0.7090 - val_acc: 0.4953
# Epoch 5/6
# 120/120 [==============================] - 23s 192ms/step - loss: 0.6578 - acc: 0.5979 - val_loss: 0.7146 - val_acc: 0.5070
# Epoch 6/6
# 120/120 [==============================] - 23s 195ms/step - loss: 0.6389 - acc: 0.6311 - val_loss: 0.7411 - val_acc: 0.4718
# Results for current fold:
# Evaluation using training data
# 30/30 [==============================] - 3s 101ms/step - loss: 0.6029 - acc: 0.6737
# Evaluation using testing data
# 4/4 [==============================] - 0s 93ms/step - loss: 0.7411 - acc: 0.4718

# %%
import statistics 

score = []
for i in results:
    score.append(i[1])
x = statistics.mean(score)
    
print("Kfold Mean: ", x)
# Out:
# Kfold Mean:  0.504225343465805

# %% [markdown]
# ### Confusion matrix

# %%
#for last fold
results2 = confusion_matrix(Y_test,prediction_val)
print ('Confusion Matrix :')
print(results2)
print ('Accuracy Score :',accuracy_score(Y_test,prediction_val))
print ('Report : ')
print (classification_report(Y_test,prediction_val))
# Out:
# Confusion Matrix :
# [[102 106]
#  [119  99]]
# Accuracy Score : 0.47183098591549294
# Report :
#               precision    recall  f1-score   support
#
#            0       0.46      0.49      0.48       208
#            1       0.48      0.45      0.47       218
#
#     accuracy                           0.47       426
#    macro avg       0.47      0.47      0.47       426
# weighted avg       0.47      0.47      0.47       426
